# %%
import cx_Oracle
import pandas as pd

# %%
conn=cx_Oracle.connect('hr/hr@70.12.116.70:1521/xe')

# %%
conn #내가 접속한 객체
# Out:
# <cx_Oracle.Connection to hr@70.12.116.70:1521/xe>

# %%
df_departments=pd.read_sql("select * from departments",con=conn)
df_departments
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
df_departments=pd.read_sql("select * from tab",con=conn)
df_departments
# Out:
#               TNAME TABTYPE CLUSTERID
# 0         COUNTRIES   TABLE      None
# 1       DEPARTMENTS   TABLE      None
# 2         EMPLOYEES   TABLE      None
# 3  EMP_DETAILS_VIEW    VIEW      None
# 4              JOBS   TABLE      None
# 5       JOB_HISTORY   TABLE      None
# 6         LOCATIONS   TABLE      None
# 7           REGIONS   TABLE      None

# %%
df_departments=pd.read_sql("select * from employees natural join departments",con=conn)
df_departments
# Out:
#     MANAGER_ID  DEPARTMENT_ID  EMPLOYEE_ID   FIRST_NAME   LAST_NAME     EMAIL  \
# 0          100             90          101        Neena     Kochhar  NKOCHHAR
# 1          100             90          102          Lex     De Haan   LDEHAAN
# 2          103             60          104        Bruce       Ernst    BERNST
# 3          103             60          105        David      Austin   DAUSTIN
# 4          103             60          106        Valli   Pataballa  VPATABAL
# 5          103             60          107        Diana     Lorentz  DLORENTZ
# 6          108            100          109       Daniel      Faviet   DFAVIET
# 7          108            100          110         John        Chen     JCHEN
# 8          108            100          111       Ismael     Sciarra  ISCIARRA
# 9          108            100          112  Jose Manuel       Urman   JMURMAN
# 10         108            100          113         Luis        Popp     LPOPP
# ...

# %%
df_departments.shape #몇행인지 알려줌
# Out:
# (32, 13)

# %%
df_departments.describe
# Out:
# <bound method NDFrame.describe of     MANAGER_ID  DEPARTMENT_ID  EMPLOYEE_ID   FIRST_NAME   LAST_NAME     EMAIL  \
# 0          100             90          101        Neena     Kochhar  NKOCHHAR
# 1          100             90          102          Lex     De Haan   LDEHAAN
# 2          103             60          104        Bruce       Ernst    BERNST
# 3          103             60          105        David      Austin   DAUSTIN
# 4          103             60          106        Valli   Pataballa  VPATABAL
# 5          103             60          107        Diana     Lorentz  DLORENTZ
# 6          108            100          109       Daniel      Faviet   DFAVIET
# 7          108            100          110         John        Chen     JCHEN
# 8          108            100          111       Ismael     Sciarra  ISCIARRA
# 9          108            100          112  Jose Manuel       Urman   JMURMAN
# 10         108            100          113         Luis        Popp     LPOPP
# ...

# %%
#네가 원하는 columm만 사용하고 싶다.
df_departments[1:4]   # 원본은 바뀌지 않는다.
# Out:
#    MANAGER_ID  DEPARTMENT_ID  EMPLOYEE_ID FIRST_NAME LAST_NAME    EMAIL  \
# 1         100             90          102        Lex   De Haan  LDEHAAN
# 2         103             60          104      Bruce     Ernst   BERNST
# 3         103             60          105      David    Austin  DAUSTIN
#
#    PHONE_NUMBER  HIRE_DATE   JOB_ID   SALARY  COMMISSION_PCT DEPARTMENT_NAME  \
# 1  515.123.4569 2001-01-13    AD_VP  17000.0             NaN       Executive
# 2  590.423.4568 2007-05-21  IT_PROG   6000.0             NaN              IT
# 3  590.423.4569 2005-06-25  IT_PROG   4800.0             NaN              IT
#
#    LOCATION_ID
# 1         1700
# 2         1400
# 3         1400

# %%
df_departments=pd.read_sql("select * from departments",con=conn)
df_departments
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
df_departments[['DEPARTMENT_ID','DEPARTMENT_NAME']] #COLUMN을 기준으로 출력한다.
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME
# 0              10        Administration
# 1              20             Marketing
# 2              30            Purchasing
# 3              40       Human Resources
# 4              50              Shipping
# 5              60                    IT
# 6              70      Public Relations
# 7              80                 Sales
# 8              90             Executive
# 9             100               Finance
# 10            110            Accounting
# 11            120              Treasury
# 12            130         Corporate Tax
# 13            140    Control And Credit
# 14            150  Shareholder Services
# 15            160              Benefits
# 16            170         Manufacturing
# 17            180          Construction
# 18            190           Contracting
# 19            200            Operations
# 20            210            IT Support
# 21            220                   NOC
# ...

# %%
df_departments[3:7] #슬라이싱은 ROW를 기준으로 출력한다.
# Out:
#    DEPARTMENT_ID   DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 3             40   Human Resources       203.0         2400
# 4             50          Shipping       121.0         1500
# 5             60                IT       103.0         1400
# 6             70  Public Relations       204.0         2700

# %%
df_departments.loc[[0,3,5]] #원하는 row만 꺼낼수 있다. row 지정이 가능하다. 자기데이터의 인덱스를 기준으로 가져온다.
# Out:
#    DEPARTMENT_ID  DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0             10   Administration       200.0         1700
# 3             40  Human Resources       203.0         2400
# 5             60               IT       103.0         1400

# %%
#location_id rk 1800 이상인 row만 선택
df_departments[df_departments.LOCATION_ID>1800]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-39f1067d7d33> in <module>
#       1 #location_id rk 1800 이상인 row만 선택
# ----> 2 df_departments[LOCATION_ID>1800]
#
# NameError: name 'LOCATION_ID' is not defined

# %%
df_departments[(df_departments.LOCATION_ID>1300)&(df_departments.DEPARTMENT_NAME=='IT')]
# Out:
#    DEPARTMENT_ID DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 5             60              IT       103.0         1400

# %%
df_departments.iloc[:,0:2] # 행렬 조작으로 슬라이싱
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME
# 0              10        Administration
# 1              20             Marketing
# 2              30            Purchasing
# 3              40       Human Resources
# 4              50              Shipping
# 5              60                    IT
# 6              70      Public Relations
# 7              80                 Sales
# 8              90             Executive
# 9             100               Finance
# 10            110            Accounting
# 11            120              Treasury
# 12            130         Corporate Tax
# 13            140    Control And Credit
# 14            150  Shareholder Services
# 15            160              Benefits
# 16            170         Manufacturing
# 17            180          Construction
# 18            190           Contracting
# 19            200            Operations
# 20            210            IT Support
# 21            220                   NOC
# ...

# %%
df_departments.iloc[[10,20,23,26],[1,3]] #실제 인덱스와 상관없이 제로베이스 인덱스를 찾는것임. //
# 뒤에 , 붙여서  [] 추가하면 특정 컬럼을 지정할수 있따.
# Out:
#      DEPARTMENT_NAME  LOCATION_ID
# 10        Accounting         1700
# 20        IT Support         1700
# 23  Government Sales         1700
# 26           Payroll         1700

# %%
df_departments.iloc[[1,3]]
# Out:
#    DEPARTMENT_ID  DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 1             20        Marketing       201.0         1800
# 3             40  Human Resources       203.0         2400

# %%
df_departments.filter(like='MENT',axis=1)
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME
# 0              10        Administration
# 1              20             Marketing
# 2              30            Purchasing
# 3              40       Human Resources
# 4              50              Shipping
# 5              60                    IT
# 6              70      Public Relations
# 7              80                 Sales
# 8              90             Executive
# 9             100               Finance
# 10            110            Accounting
# 11            120              Treasury
# 12            130         Corporate Tax
# 13            140    Control And Credit
# 14            150  Shareholder Services
# 15            160              Benefits
# 16            170         Manufacturing
# 17            180          Construction
# 18            190           Contracting
# 19            200            Operations
# 20            210            IT Support
# 21            220                   NOC
# ...

# %%
df_departments.filter(like='ID',axis=1).head()
# Out:
#    DEPARTMENT_ID  MANAGER_ID  LOCATION_ID
# 0             10       200.0         1700
# 1             20       201.0         1800
# 2             30       114.0         1700
# 3             40       203.0         2400
# 4             50       121.0         1500

# %%
df_departments.drop(df_departments.index[[0,5]])
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# 13            140    Control And Credit         NaN         1700
# 14            150  Shareholder Services         NaN         1700
# ...

# %%
df_departments.drop('DEPARTMENT_ID',axis=1)  #컬럼 삭제
# Out:
#          DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0         Administration       200.0         1700
# 1              Marketing       201.0         1800
# 2             Purchasing       114.0         1700
# 3        Human Resources       203.0         2400
# 4               Shipping       121.0         1500
# 5                     IT       103.0         1400
# 6       Public Relations       204.0         2700
# 7                  Sales       145.0         2500
# 8              Executive       100.0         1700
# 9                Finance       108.0         1700
# 10            Accounting       205.0         1700
# 11              Treasury         NaN         1700
# 12         Corporate Tax         NaN         1700
# 13    Control And Credit         NaN         1700
# 14  Shareholder Services         NaN         1700
# 15              Benefits         NaN         1700
# 16         Manufacturing         NaN         1700
# 17          Construction         NaN         1700
# ...

# %%
df=pd.read_csv("student.csv")   #나는 csv형식으로 읽을 것이다. (엑셀)
df
# Out:
#     이름  나이        주소
# 0  강경미  30  경기도 고양시
# 1  고길동  20   서울시 노원구
# 2  개나리  19   서울시 강남구
